# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/sample_data/Farm_Yields.csv",index_col="Farmer")

# %%
df1=df

# %%
df1
# Out:
#          Rice  Wheat  Corn  Millets
# Farmer
# Ravi       22     20    37       13
# Saju       18     21    43       15
# Kishore    17     14    25       28
# Satish     12     16    52        8

# %%
#a*x=b
#x=a^-1*b

# %%
n1=np.matrix(df1)

# %%
n1
# Out:
# matrix([[22, 20, 37, 13],
#         [18, 21, 43, 15],
#         [17, 14, 25, 28],
#         [12, 16, 52,  8]])

# %%
n3=np.matrix([373,394,922,299])

# %%
n3
# Out:
# matrix([[373, 394, 922, 299]])

# %%
from numpy.linalg import inv

# %%
n1=inv(n1)
n1
# Out:
# matrix([[ 0.19836957, -0.23845109,  0.02275815,  0.04509171],
#         [-0.14855072,  0.35778986, -0.07925725, -0.15206069],
#         [ 0.00815217, -0.05774457,  0.01120924,  0.05579144],
#         [-0.05344203,  0.01743659,  0.05151721, -0.00116055]])

# %%
n2=n3@n1

# %%
n2=np.array(n2)[0]

# %%
x=pd.DataFrame(n2,index=df1.index)

# %%
x
# Out:
#            0
# Farmer
# Ravi     7.0
# Saju     4.0
# Kishore  3.0
# Satish   8.0

# %%
x.plot()
# Out:
# <Axes: xlabel='Farmer'>
