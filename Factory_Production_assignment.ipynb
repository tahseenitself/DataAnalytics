# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("/content/sample_data/Factory_Production.csv")

# %%
df2=pd.read_csv("/content/sample_data/Factory_Production.csv")

# %%
df2
# Out:
#   Factory  Generators  Motors  Cables  Days
# 0       A           8      17     232   352
# 1       B           6      20     203   348
# 2       C          10      16     187   337
# 3       D           7      24     218   357
# 4       E          13      13     256   362
# 5       F           9      11     179   365
# 6       G           7      15     156   339
# 7       H           5       8     223   324
# 8       I          12      18     187   316
# 9       J          11      22     210   346

# %%
n1=np.array(df1["Days"])

# %%
n1
# Out:
# array([352, 348, 337, 357, 362, 365, 339, 324, 316, 346])

# %%
n2=np.array(df1.iloc[:,1:4])

# %%
n2
# Out:
# array([[  8,  17, 232],
#        [  6,  20, 203],
#        [ 10,  16, 187],
#        [  7,  24, 218],
#        [ 13,  13, 256],
#        [  9,  11, 179],
#        [  7,  15, 156],
#        [  5,   8, 223],
#        [ 12,  18, 187],
#        [ 11,  22, 210]])

# %%
n3=n1@n2

# %%
n3=pd.DataFrame(n3,index=[1,2,3],columns=["Production Values"])

# %%
n3
# Out:
#    Production Values
# 1              30355
# 2              56602
# 3             708048

# %% [markdown]
# Observations:
